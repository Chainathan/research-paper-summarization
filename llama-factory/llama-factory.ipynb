# %% [markdown]
# # LLaMA Factory Colab Tutorial
#
# Please use a **free** Tesla T4 Colab GPU to run this!
#
# Project homepage: https://github.com/hiyouga/LLaMA-Factory

# %% [markdown]
# ## Install Dependencies

# %%
##### %rm -rf LLaMA-Factory
# !git clone https://github.com/hiyouga/LLaMA-Factory.git
# %cd /kaggle/working/LLaMA-Factory
# %ls
# !pip install .
# !pip install .[bitsandbytes]
# %%capture
# !pip install -U xformers --index-url https://download.pytorch.org/whl/cu121
# !pip install "unsloth[kaggle-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install "unsloth[cu121-torch211] @ git+https://github.com/unslothai/unsloth.git"

# Temporary fix for https://github.com/huggingface/datasets/issues/6753
# !pip install datasets==2.16.0 fsspec==2023.10.0 gcsfs==2023.10.0
# Out:
# fatal: destination path 'LLaMA-Factory' already exists and is not an empty directory.
# /kaggle/working/LLaMA-Factory
# CITATION.cff    build/                         requirements.txt
# Dockerfile      data/                          scripts/
# LICENSE         docker-compose.yml             setup.py
# LLaMA-Factory/  evaluation/                    src/
# Makefile        examples/                      state.db
# README.md       huggingface_tokenizers_cache/  test_identity/
# README_zh.md    pyproject.toml                 tests/
# assets/         qwen_out/                      wandb/
# Processing /kaggle/working/LLaMA-Factory
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=1.13.1 in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (2.1.2)
# Requirement already satisfied: transformers>=4.37.2 in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (4.39.3)
# Requirement already satisfied: datasets>=2.14.3 in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (2.18.0)
# Requirement already satisfied: accelerate>=0.27.2 in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (0.28.0)
# Collecting peft>=0.10.0 (from llmtuner==0.6.3.dev0)
#   Downloading peft-0.10.0-py3-none-any.whl.metadata (13 kB)
# Collecting trl>=0.8.1 (from llmtuner==0.6.3.dev0)
#   Downloading trl-0.8.3-py3-none-any.whl.metadata (11 kB)
# Collecting gradio<=4.21.0,>=4.0.0 (from llmtuner==0.6.3.dev0)
#   Downloading gradio-4.21.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (1.11.4)
# Collecting einops (from llmtuner==0.6.3.dev0)
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (0.2.0)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (3.20.3)
# Requirement already satisfied: uvicorn in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (0.25.0)
# Requirement already satisfied: pydantic in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (2.5.3)
# Requirement already satisfied: fastapi in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (0.108.0)
# Collecting sse-starlette (from llmtuner==0.6.3.dev0)
#   Downloading sse_starlette-2.1.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (3.7.5)
# Collecting fire (from llmtuner==0.6.3.dev0)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 1.4 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.27.2->llmtuner==0.6.3.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.27.2->llmtuner==0.6.3.dev0) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.27.2->llmtuner==0.6.3.dev0) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.27.2->llmtuner==0.6.3.dev0) (6.0.1)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.27.2->llmtuner==0.6.3.dev0) (0.22.2)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.27.2->llmtuner==0.6.3.dev0) (0.4.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (15.0.2)
# Requirement already satisfied: pyarrow-hotfix in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (2.1.4)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (4.66.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.2.0,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.2.0,>=2023.1.0->datasets>=2.14.3->llmtuner==0.6.3.dev0) (2024.2.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (3.9.1)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (22.1.0)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (5.3.0)
# Collecting ffmpy (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0)
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.12.0 (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0)
#   Downloading gradio_client-0.12.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.27.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (2.1.3)
# Requirement already satisfied: orjson~=3.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (3.9.10)
# Requirement already satisfied: pillow<11.0,>=8.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (9.5.0)
# Requirement already satisfied: pydub in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.25.1)
# Collecting python-multipart>=0.0.9 (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Collecting ruff>=0.2.2 (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0)
#   Downloading ruff-0.3.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (23 kB)
# Collecting semantic-version~=2.0 (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.9 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (4.9.0)
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.12.0->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->llmtuner==0.6.3.dev0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->llmtuner==0.6.3.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->llmtuner==0.6.3.dev0) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->llmtuner==0.6.3.dev0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->llmtuner==0.6.3.dev0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->llmtuner==0.6.3.dev0) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic->llmtuner==0.6.3.dev0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic->llmtuner==0.6.3.dev0) (2.14.6)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.1->llmtuner==0.6.3.dev0) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.1->llmtuner==0.6.3.dev0) (3.2.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.37.2->llmtuner==0.6.3.dev0) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.37.2->llmtuner==0.6.3.dev0) (0.15.2)
# Collecting tyro>=0.5.11 (from trl>=0.8.1->llmtuner==0.6.3.dev0)
#   Downloading tyro-0.8.3-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn->llmtuner==0.6.3.dev0) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn->llmtuner==0.6.3.dev0) (0.14.0)
# Requirement already satisfied: starlette<0.33.0,>=0.29.0 in /opt/conda/lib/python3.10/site-packages (from fastapi->llmtuner==0.6.3.dev0) (0.32.0.post1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fire->llmtuner==0.6.3.dev0) (1.16.0)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from fire->llmtuner==0.6.3.dev0) (2.4.0)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from sse-starlette->llmtuner==0.6.3.dev0) (4.2.0)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (4.20.0)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.12.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.14.3->llmtuner==0.6.3.dev0) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.14.3->llmtuner==0.6.3.dev0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.14.3->llmtuner==0.6.3.dev0) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.14.3->llmtuner==0.6.3.dev0) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.14.3->llmtuner==0.6.3.dev0) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.14.3->llmtuner==0.6.3.dev0) (4.0.3)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx>=0.24.1->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx>=0.24.1->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from httpx>=0.24.1->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (3.6)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx>=0.24.1->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets>=2.14.3->llmtuner==0.6.3.dev0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets>=2.14.3->llmtuner==0.6.3.dev0) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets>=2.14.3->llmtuner==0.6.3.dev0) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets>=2.14.3->llmtuner==0.6.3.dev0) (1.26.18)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->sse-starlette->llmtuner==0.6.3.dev0) (1.2.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (13.7.0)
# Requirement already satisfied: docstring-parser>=0.14.1 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl>=0.8.1->llmtuner==0.6.3.dev0) (0.15)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl>=0.8.1->llmtuner==0.6.3.dev0)
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13.1->llmtuner==0.6.3.dev0) (1.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.16.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.1.2)
# Downloading gradio-4.21.0-py3-none-any.whl (17.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 42.8 MB/s eta 0:00:0000:0100:01
# Downloading gradio_client-0.12.0-py3-none-any.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 kB 18.0 MB/s eta 0:00:00
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading peft-0.10.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 14.9 MB/s eta 0:00:00
# Downloading trl-0.8.3-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.1/244.1 kB 18.1 MB/s eta 0:00:00
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 3.3 MB/s eta 0:00:00
# Downloading sse_starlette-2.1.0-py3-none-any.whl (9.2 kB)
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading ruff-0.3.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 64.7 MB/s eta 0:00:0000:01:00:01
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading tyro-0.8.3-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.0/102.0 kB 7.8 MB/s eta 0:00:00
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 11.7 MB/s eta 0:00:00
# Building wheels for collected packages: llmtuner, fire, ffmpy
#   Building wheel for llmtuner (pyproject.toml) ... done
#   Created wheel for llmtuner: filename=llmtuner-0.6.3.dev0-py3-none-any.whl size=141362 sha256=a4de55d9c2d0cf78cd58b6cdc3d4831c0dfab62d300c4f4916ea028764f2b58a
#   Stored in directory: /root/.cache/pip/wheels/21/5a/a2/9a8fea19e68e32089e22401d08554f51119f2464cad3a126ec
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117031 sha256=a9835cb8d0a111dbbb98e7f38a58ef8116e39ff96f58500b32ded9cb5fff0f28
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5584 sha256=f3fe474b1d677bc201d75dc335a28bbe7257692e2495a09dbe078f92f8a54f69
#   Stored in directory: /root/.cache/pip/wheels/bd/65/9a/671fc6dcde07d4418df0c592f8df512b26d7a0029c2a23dd81
# Successfully built llmtuner fire ffmpy
# Installing collected packages: ffmpy, websockets, tomlkit, shtab, semantic-version, ruff, python-multipart, fire, einops, tyro, sse-starlette, gradio-client, trl, peft, gradio, llmtuner
#   Attempting uninstall: websockets
#     Found existing installation: websockets 12.0
#     Uninstalling websockets-12.0:
#       Successfully uninstalled websockets-12.0
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.12.4
#     Uninstalling tomlkit-0.12.4:
#       Successfully uninstalled tomlkit-0.12.4
# Successfully installed einops-0.7.0 ffmpy-0.3.2 fire-0.6.0 gradio-4.21.0 gradio-client-0.12.0 llmtuner-0.6.3.dev0 peft-0.10.0 python-multipart-0.0.9 ruff-0.3.7 semantic-version-2.10.0 shtab-1.7.1 sse-starlette-2.1.0 tomlkit-0.12.0 trl-0.8.3 tyro-0.8.3 websockets-11.0.3
# Processing /kaggle/working/LLaMA-Factory
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=1.13.1 in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (2.1.2)
# Requirement already satisfied: transformers>=4.37.2 in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (4.39.3)
# Requirement already satisfied: datasets>=2.14.3 in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (2.18.0)
# Requirement already satisfied: accelerate>=0.27.2 in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (0.28.0)
# Requirement already satisfied: peft>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (0.10.0)
# Requirement already satisfied: trl>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (0.8.3)
# Requirement already satisfied: gradio<=4.21.0,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (4.21.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (1.11.4)
# Requirement already satisfied: einops in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (0.7.0)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (0.2.0)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (3.20.3)
# Requirement already satisfied: uvicorn in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (0.25.0)
# Requirement already satisfied: pydantic in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (2.5.3)
# Requirement already satisfied: fastapi in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (0.108.0)
# Requirement already satisfied: sse-starlette in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (2.1.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (3.7.5)
# Requirement already satisfied: fire in /opt/conda/lib/python3.10/site-packages (from llmtuner==0.6.3.dev0) (0.6.0)
# Collecting bitsandbytes>=0.39.0 (from llmtuner==0.6.3.dev0)
#   Downloading bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.27.2->llmtuner==0.6.3.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.27.2->llmtuner==0.6.3.dev0) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.27.2->llmtuner==0.6.3.dev0) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.27.2->llmtuner==0.6.3.dev0) (6.0.1)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.27.2->llmtuner==0.6.3.dev0) (0.22.2)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.27.2->llmtuner==0.6.3.dev0) (0.4.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (15.0.2)
# Requirement already satisfied: pyarrow-hotfix in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (2.1.4)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (4.66.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.2.0,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.2.0,>=2023.1.0->datasets>=2.14.3->llmtuner==0.6.3.dev0) (2024.2.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets>=2.14.3->llmtuner==0.6.3.dev0) (3.9.1)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (22.1.0)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (5.3.0)
# Requirement already satisfied: ffmpy in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.3.2)
# Requirement already satisfied: gradio-client==0.12.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.12.0)
# Requirement already satisfied: httpx>=0.24.1 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.27.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (2.1.3)
# Requirement already satisfied: orjson~=3.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (3.9.10)
# Requirement already satisfied: pillow<11.0,>=8.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (9.5.0)
# Requirement already satisfied: pydub in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.0.9)
# Requirement already satisfied: ruff>=0.2.2 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.3.7)
# Requirement already satisfied: semantic-version~=2.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.9 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/conda/lib/python3.10/site-packages (from gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (4.9.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /opt/conda/lib/python3.10/site-packages (from gradio-client==0.12.0->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (11.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->llmtuner==0.6.3.dev0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->llmtuner==0.6.3.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->llmtuner==0.6.3.dev0) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->llmtuner==0.6.3.dev0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->llmtuner==0.6.3.dev0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->llmtuner==0.6.3.dev0) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic->llmtuner==0.6.3.dev0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic->llmtuner==0.6.3.dev0) (2.14.6)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.1->llmtuner==0.6.3.dev0) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.1->llmtuner==0.6.3.dev0) (3.2.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.37.2->llmtuner==0.6.3.dev0) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.37.2->llmtuner==0.6.3.dev0) (0.15.2)
# Requirement already satisfied: tyro>=0.5.11 in /opt/conda/lib/python3.10/site-packages (from trl>=0.8.1->llmtuner==0.6.3.dev0) (0.8.3)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn->llmtuner==0.6.3.dev0) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn->llmtuner==0.6.3.dev0) (0.14.0)
# Requirement already satisfied: starlette<0.33.0,>=0.29.0 in /opt/conda/lib/python3.10/site-packages (from fastapi->llmtuner==0.6.3.dev0) (0.32.0.post1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fire->llmtuner==0.6.3.dev0) (1.16.0)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from fire->llmtuner==0.6.3.dev0) (2.4.0)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from sse-starlette->llmtuner==0.6.3.dev0) (4.2.0)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (4.20.0)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.12.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.14.3->llmtuner==0.6.3.dev0) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.14.3->llmtuner==0.6.3.dev0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.14.3->llmtuner==0.6.3.dev0) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.14.3->llmtuner==0.6.3.dev0) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.14.3->llmtuner==0.6.3.dev0) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.14.3->llmtuner==0.6.3.dev0) (4.0.3)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx>=0.24.1->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx>=0.24.1->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (1.0.5)
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from httpx>=0.24.1->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (3.6)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx>=0.24.1->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets>=2.14.3->llmtuner==0.6.3.dev0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets>=2.14.3->llmtuner==0.6.3.dev0) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets>=2.14.3->llmtuner==0.6.3.dev0) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets>=2.14.3->llmtuner==0.6.3.dev0) (1.26.18)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio->sse-starlette->llmtuner==0.6.3.dev0) (1.2.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (13.7.0)
# Requirement already satisfied: docstring-parser>=0.14.1 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl>=0.8.1->llmtuner==0.6.3.dev0) (0.15)
# Requirement already satisfied: shtab>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl>=0.8.1->llmtuner==0.6.3.dev0) (1.7.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13.1->llmtuner==0.6.3.dev0) (1.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.16.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio<=4.21.0,>=4.0.0->llmtuner==0.6.3.dev0) (0.1.2)
# Downloading bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl (119.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 12.6 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: llmtuner
#   Building wheel for llmtuner (pyproject.toml) ... done
#   Created wheel for llmtuner: filename=llmtuner-0.6.3.dev0-py3-none-any.whl size=141362 sha256=c3413a1f66daa41993ba860bf59e5e1c1498add1526b70a97ed7649b0ec6e56d
#   Stored in directory: /root/.cache/pip/wheels/21/5a/a2/9a8fea19e68e32089e22401d08554f51119f2464cad3a126ec
# Successfully built llmtuner
# Installing collected packages: bitsandbytes, llmtuner
#   Attempting uninstall: llmtuner
#     Found existing installation: llmtuner 0.6.3.dev0
#     Uninstalling llmtuner-0.6.3.dev0:
#       Successfully uninstalled llmtuner-0.6.3.dev0
# Successfully installed bitsandbytes-0.43.1 llmtuner-0.6.3.dev0
# Collecting unsloth@ git+https://github.com/unslothai/unsloth.git (from unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git)
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-ejb435ap/unsloth_8b4927350c12421b9483407cbbe054a6
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-ejb435ap/unsloth_8b4927350c12421b9483407cbbe054a6
#   Resolved https://github.com/unslothai/unsloth.git to commit d215fd902cf28feb8abcfde2d25281d0fbf9d28c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: bitsandbytes in /opt/conda/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (0.43.1)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (2.1.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (1.26.4)
# Collecting xformers@ https://download.pytorch.org/whl/cu121/xformers-0.0.23-cp310-cp310-manylinux2014_x86_64.whl (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading https://download.pytorch.org/whl/cu121/xformers-0.0.23-cp310-cp310-manylinux2014_x86_64.whl (213.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 MB 3.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tyro in /opt/conda/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (0.8.3)
# Requirement already satisfied: transformers>=4.38.2 in /opt/conda/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (4.39.3)
# Requirement already satisfied: datasets>=2.16.0 in /opt/conda/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (2.18.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (4.66.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (5.9.3)
# Requirement already satisfied: wheel>=0.42.0 in /opt/conda/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (0.42.0)
# Requirement already satisfied: accelerate>=0.26.1 in /opt/conda/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (0.28.0)
# Requirement already satisfied: trl>=0.7.9 in /opt/conda/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (0.8.3)
# Requirement already satisfied: peft>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (0.10.0)
# Requirement already satisfied: protobuf<4.0.0 in /opt/conda/lib/python3.10/site-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (3.20.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.26.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (21.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.26.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (6.0.1)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.26.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (0.22.2)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate>=0.26.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (0.4.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (15.0.2)
# Requirement already satisfied: pyarrow-hotfix in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (2.1.4)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (2.31.0)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (0.70.16)
# Requirement already satisfied: fsspec<=2024.2.0,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.2.0,>=2023.1.0->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (2024.2.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (3.9.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.38.2->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.38.2->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (0.15.2)
# Requirement already satisfied: docstring-parser>=0.14.1 in /opt/conda/lib/python3.10/site-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (0.15)
# Requirement already satisfied: rich>=11.1.0 in /opt/conda/lib/python3.10/site-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (13.7.0)
# Requirement already satisfied: shtab>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (1.7.1)
# Collecting torch (from bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading torch-2.1.1-cp310-cp310-manylinux1_x86_64.whl.metadata (25 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.18.1 (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.1.0 (from torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (4.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->accelerate>=0.26.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (2.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->bitsandbytes->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[cu121-torch211]@ git+https://github.com/unslothai/unsloth.git) (1.16.0)
# Downloading torch-2.1.1-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 44.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 45.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 41.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 4.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 18.3 MB/s eta 0:00:0000:0100:01m
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 12.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 8.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 7.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.4 MB/s eta 0:00:00
# Downloading triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 17.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 51.7 MB/s eta 0:00:0000:01:00:01
# Building wheels for collected packages: unsloth
#   Building wheel for unsloth (pyproject.toml) ... done
#   Created wheel for unsloth: filename=unsloth-2024.4-py3-none-any.whl size=97341 sha256=a39757d88a3c16714fd6dbfb75cf3aac2ac9df1167df6f91384d801d97029624
#   Stored in directory: /tmp/pip-ephem-wheel-cache-39qpfa5s/wheels/ed/d4/e9/76fb290ee3df0a5fc21ce5c2c788e29e9607a2353d8342fd0d
# Successfully built unsloth
# Installing collected packages: unsloth, triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, xformers
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.2
#     Uninstalling torch-2.1.2:
#       Successfully uninstalled torch-2.1.2
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 torch-2.1.1 triton-2.1.0 unsloth-2024.4 xformers-0.0.23

# %% [markdown]
# ### Check GPU environment

# %%
import torch
try:
  assert torch.cuda.is_available() is True
except AssertionError:
  print("Please set up a GPU before using LLaMA Factory: https://medium.com/mlearning-ai/training-yolov4-on-google-colab-316f8fff99c6")

# %% [markdown]
# ### Log in with Hugging Face account to upload model (Optional)

# %%
# !python -c “from huggingface_hub.hf_api import HfFolder; HfFolder.save_token(‘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’)”
# !huggingface-cli login
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `$'\342\200\230hf_jgNmAGTQhsUQZNquWjPjuuAJBSUnzPnoPx\342\200\231''
# /bin/bash: -c: line 0: `python -c “from huggingface_hub.hf_api import HfFolder; HfFolder.save_token(‘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’)”'

# %% [markdown]
# ## Fine-tune model via LLaMA Board

# %% [markdown]
# ## Fine-tune model via Command Line

# %%
# gc.collect()
torch.cuda.empty_cache()

# %%
import os

# Set environment variables
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1'
os.environ["WANDB_DISABLED"] = "true"

# model and data
model_name = "unsloth/mistral-7b-instruct-v0.2-bnb-4bit"
# model_name = "unsloth/llama-2-7b-bnb-4bit"
# model_name = "unsloth/gemma-7b-bnb-4bit"
dataset_dir = "/kaggle/input/json-arxiv"
dataset_name = "data_json"
template = "alpaca"
output_dir = "./mistral"

# hyperparams
learning_rate = 5e-5
num_epochs = 3.0
warmup_ratio = 1/num_epochs
lr_sched = "cosine"
optim = "adamw_bnb_8bit"

# bs
per_device_train_batch_size = 2 # 1 for gemma
per_device_eval_batch_size = 2 # 1 for gemma
gradient_accumulation_steps = 4
cutoff = 2048 # input token cutoff length
dataloader_num_workers = 2
preprocessing_num_workers = 16
# rope_scaling = "dynamic" # {linear,dynamic,None} - for making normal model work with longer context in a simpler way

# steps
eval_steps = 500
save_steps = 500
logging_steps = 50
save_total_limit = 20

#lora
lora_target = "q_proj,k_proj,v_proj,o_proj,gate_proj,up_proj,down_proj"
lora_rank = 8
lora_alpha = 8

# TODO
# tensor board
# checkpointing
# huggingface saves

# Construct the command using f-string
command = f"""
accelerate launch \
    --num_processes=2 \
    ./src/train_bash.py \
    --stage sft \
    --do_train \
    --model_name_or_path {model_name} \
    --dataset_dir {dataset_dir} \
    --dataset {dataset_name} \
    --template {template} \
    --finetuning_type lora \
    --lora_target {lora_target} \
    --lora_rank {lora_rank} \
    --lora_alpha {lora_alpha} \
    --output_dir {output_dir} \
    --overwrite_cache \
    --overwrite_output_dir \
    --cutoff_len {cutoff} \
    --preprocessing_num_workers {preprocessing_num_workers} \
    --dataloader_num_workers {dataloader_num_workers} \
    --per_device_train_batch_size {per_device_train_batch_size} \
    --per_device_eval_batch_size {per_device_eval_batch_size} \
    --gradient_accumulation_steps {gradient_accumulation_steps} \
    --lr_scheduler_type {lr_sched} \
    --warmup_ratio {warmup_ratio} \
    --logging_steps {logging_steps} \
    --save_steps {save_steps} \
    --eval_steps {eval_steps} \
    --save_total_limit {save_total_limit} \
    --evaluation_strategy steps \
    --load_best_model_at_end \
    --learning_rate {learning_rate} \
    --optim {optim} \
    --num_train_epochs {num_epochs} \
    --val_size 0.1 \
    --ddp_timeout 180000000 \
    --plot_loss \
    --fp16 \
    --use_unsloth \
    --quantization_bit 4 \
    --auto_find_batch_size \
    --packing
"""

# Execute the command
# !{command}

# %% [markdown]
# ### Infer the fine-tuned model

# %%
from llmtuner import ChatModel
chat_model = ChatModel(dict(
  model_name_or_path="Qwen/Qwen1.5-0.5B-Chat",
  adapter_name_or_path="test_identity", # output dir of our training
  finetuning_type="lora",
  template="qwen", # change to alpaca
))
messages = []
while True:
  query = input("\nUser: ")
  if query.strip() == "exit":
    break
  if query.strip() == "clear":
    messages = []
    continue

  messages.append({"role": "user", "content": query})
  print("Assistant: ", end="", flush=True)
  response = ""
  for new_text in chat_model.stream_chat(messages):
    print(new_text, end="", flush=True)
    response += new_text
  print()
  messages.append({"role": "assistant", "content": response})

# %% [markdown]
# ### Merge LoRA weights

# %%
from llmtuner import export_model
export_model(dict(
  model_name_or_path="Qwen/Qwen1.5-0.5B-Chat",
  adapter_name_or_path="test_identity",
  finetuning_type="lora",
  template="qwen",
  export_dir="test_exported",
  # export_hub_model_id="your_hf_id/test_identity",
))
